# %%
import pandas as pd
import numpy as np
import librosa

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

from secret import *
from IPython.display import clear_output

client_credentials_manager = SpotifyClientCredentials(client_id=spotify_credentials['client_id'],
                                                      client_secret=spotify_credentials['client_secret'])

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

songs = pd.read_csv('../data/all_decades_songs_V3.csv', index_col=0)
songs.head()
# Out:
#                 artist                             song  decade  \
# 0           Gene Autry  Rudolph, The Red-nosed Reindeer    1950
# 1  The Andrews Sisters             I Can Dream, Can't I    1950
# 2    The Ames Brothers                          Rag Mop    1950
# 3            Red Foley      Chattanoogie Shoe Shine Boy    1950
# 4        Teresa Brewer             Music! Music! Music!    1950
#
#                  track_id                                        preview_url  \
# 0  6ymkab3FTjiFzSJwhal59m  https://audio-ssl.itunes.apple.com/itunes-asse...
# 1  4oP8eYnsSKJPC4VNfPB7dZ  https://audio-ssl.itunes.apple.com/itunes-asse...
# 2  0fVtEGoXeRhllDU9ChQAZl  https://p.scdn.co/mp3-preview/ebd8099b71ecd6f1...
# 3  7Jf323ttHKUnPylFWiaGl3  https://audio-ssl.itunes.apple.com/itunes-asse...
# 4  0lO5EKoz1Rb1pJoPoldE4D  https://audio-ssl.itunes.apple.com/itunes-asse...
#
#                                           track_name          artist_name  \
# ...

# %%
spotify_features = []
for i,row in songs.iterrows():
    features = sp.audio_features(row['track_id'])
    spotify_features.append(features)
    
    clear_output(wait=True)
    print(f"{i+1}/{len(songs)}")
# Out:
# 1189/1189

# %%
len(spotify_features)
# Out:
# 1189

# %%
# spotify_features[1][0]
spotify_features_data = []
for i in range(1189):
    spotify_features_data.append(spotify_features[i][0])
spotify_features_data
# Out:
# [{'danceability': 0.596,
#   'energy': 0.315,
#   'key': 8,
#   'loudness': -9.175,
#   'mode': 1,
#   'speechiness': 0.0428,
#   'acousticness': 0.961,
#   'instrumentalness': 0,
#   'liveness': 0.258,
#   'valence': 0.64,
#   'tempo': 119.935,
#   'type': 'audio_features',
#   'id': '6ymkab3FTjiFzSJwhal59m',
#   'uri': 'spotify:track:6ymkab3FTjiFzSJwhal59m',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ymkab3FTjiFzSJwhal59m',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ymkab3FTjiFzSJwhal59m',
#   'duration_ms': 171773,
#   'time_signature': 4},
#  {'danceability': 0.27,
#   'energy': 0.177,
#   'key': 0,
#   'loudness': -9.791,
#   'mode': 1,
#   'speechiness': 0.0298,
#   'acousticness': 0.922,
#   'instrumentalness': 0,
#   'liveness': 0.104,
#   'valence': 0.237,
#   'tempo': 87.373,
#   'type': 'audio_features',
#   'id': '4oP8eYnsSKJPC4VNfPB7dZ',
#   'uri': 'spotify:track:4oP8eYnsSKJPC4VNfPB7dZ',
# ...

# %%
spotify_features_df = pd.DataFrame(spotify_features_data)
spotify_features_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.596   0.315    8    -9.175     1       0.0428         0.961
# 1            0.270   0.177    0    -9.791     1       0.0298         0.922
# 2            0.589   0.396    7   -13.580     1       0.2370         0.705
# 3            0.725   0.373   10   -15.925     1       0.0494         0.613
# 4            0.752   0.443    2   -14.392     1       0.0398         0.667
# ...            ...     ...  ...       ...   ...          ...           ...
# 1184         0.501   0.405    1    -5.679     1       0.0319         0.751
# 1185         0.488   0.343    4    -8.985     1       0.0436         0.556
# 1186         0.695   0.762    0    -3.497     1       0.0395         0.192
# 1187         0.544   0.729    1    -3.911     0       0.0981         0.105
# 1188         0.562   0.937    9    -4.059     0       0.0596         0.315
#
# ...

# %%
spotify_features_df.to_csv('../data/spotify_features.csv')
